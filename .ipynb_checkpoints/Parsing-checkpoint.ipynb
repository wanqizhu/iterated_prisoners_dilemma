# %%
import glob
import csv
import pandas as pd
import numpy as np

#MY ATTEMPT ON TRYING TO MAKE IT EFFICENT EVEN THOUGH ITS BS
# AvgTable = pd.read_csv('./test.csv', index_col='Name')
# #adds new column
# AvgTable['Times_played'] = 1

# #Loading and Parsing
# for file in glob.glob('./*.csv'):
#     table = pd.read_csv(file, index_col='Name')
#     for i, r in table.iterrows():
#         if(i in AvgTable.index):
#             AvgTable.loc[i,'Times_played']+=1
#             timesPlayed = AvgTable.loc[i,'Times_played']
#             for column in table:
#                 AvgTable.loc[i,column]*=(timesPlayed-1)
#                 AvgTable.loc[i,column]+=table.loc[i,column]
#                 AvgTable.loc[i,column]/=(timesPlayed)
#         else:
#             AvgTable.append(table.loc[i])
#             AvgTable.loc[i,'Times_played']=1
# print(AvgTable)            
# AvgTable.head()

# %%
#Summing all the csv files and just meaning by subgroup defined by name
#SumTable = pd.read_csv('data/tour_1_result_0.csv')
list_ = []
for file in glob.glob('data/tour*result*.csv'):
    table = pd.read_csv(file)
    list_.append(table)
SumTable = pd.concat(list_, ignore_index=True)
AvgTable = SumTable.groupby('Name').mean()
AvgTable.head(AvgTable.size).sort_values(['Rank'])

# %%
len(list_)
# Out:
# 1227

# %%
x_train = np.zeros((20,13,207))
y_train = np.zeros((20,13,207))

print(AvgTable.index) 
tournamentNumber=0
for file in glob.glob('./*.csv'):
    table = pd.read_csv(file)
    x_train_layer = AvgTable
    for i, r in table.iterrows():
        if(r['Name'] in AvgTable.index):
            x_train_layer.index['Name']=1
# Out:
# Index(['$\phi$', '$\pi$', '$e$', 'ALLCorALLD', 'Adaptive',
#        'Adaptive Pavlov 2006', 'Adaptive Pavlov 2011', 'Aggravater',
#        'Alexei: (D,)', 'Alternator Hunter',
#        ...
#        'ZD-Extort-2 v2: 0.125, 0.5, 1', 'ZD-Extort-2: 0.1111111111111111, 0.5',
#        'ZD-Extort-4: 0.23529411764705882, 0.25, 1',
#        'ZD-Extort3: 0.11538461538461539, 0.3333333333333333, 1',
#        'ZD-Extortion: 0.2, 0.1, 1', 'ZD-GEN-2: 0.125, 0.5, 3',
#        'ZD-GTFT-2: 0.25, 0.5', 'ZD-Mem2', 'ZD-Mischief: 0.1, 0.0, 1',
#        'ZD-SET-2: 0.25, 0.0, 2'],
#       dtype='object', name='Name', length=207)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-291-0c9fcc304180> in <module>()
#      11     for i, r in table.iterrows():
#      12         if(r['Name'] in AvgTable.index):
# ---> 13             x_train_layer.index['Name']=1
#
# /anaconda2/envs/ipd/lib/python3.6/site-packages/pandas/core/indexes/base.py in __setitem__(self, key, value)
#    1722
#    1723     def __setitem__(self, key, value):
# -> 1724         raise TypeError("Index does not support mutable operations")
#    1725
#    1726     def __getitem__(self, key):
#
# TypeError: Index does not support mutable operations

# %%
from keras.models import Sequential
from keras.layers import Dense

#basic sequenctial keras NN model with 2 layers.
#Input are vectors of strategies that participate in the tournament
#Output is prediction of 1 hot vector representing the 5 most dominant strategies in the tournament
model = Sequential()

model.add(Dense(units=400, activation='relu', input_shape=(13,207)))
model.add(Dense(units=300, activation='relu'))
model.add(Dense(units=207, activation='relu'))

model.compile(loss='categorical_crossentropy',
              optimizer='sgd',
              metrics=['accuracy'])

model.fit